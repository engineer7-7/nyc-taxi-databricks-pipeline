# %%
gold_config = [
    '/Workspace/Users/nikolaoschatziminas@gmail.com/taxi_nyc_project/nyc-taxi-databricks-pipeline/gold_notebooks/gold_taxi_nyc'
]

# %%
dbutils.notebook.run(gold_config[0], 3600)
print(f'{gold_config[0]} run succesfully.')
