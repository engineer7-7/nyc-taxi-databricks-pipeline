# %%
silver_notebook_path = [
    '/Workspace/Users/nikolaoschatziminas@gmail.com/taxi_nyc_project/nyc-taxi-databricks-pipeline/silver_notebooks/silver_taxi_nyc'
]

# %%
dbutils.notebook.run(silver_notebook_path[0], 3600)
print(f'{silver_notebook_path[0]} run succesfully.')
